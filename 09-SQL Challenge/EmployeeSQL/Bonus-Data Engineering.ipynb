# %%
# Load Dependencies

# Data Organization & Collection
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# Data Visualization & Analysis
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
import gmaps

# %%
engine = create_engine('postgresql://username:password@localhost:5432/Employee_DB')
connection = engine.connect()

# %% [markdown]
# ## 1. Create a histogram to visualize the most common salary ranges for employees.

# %%
# Get average salary and title from the Salary table in the Postgres Employee_DB using connection created in previous steps using SQLAlchemy 
## Refer to 9. Bonus in final_querits.sql in the postgres db queries.
sal_df = pd.read_sql('SELECT * FROM Salaries', con=engine)
sal_df

# Create a bar chart
plt.figure(figsize=(10,5))
plt.hist(sal_df['salary'], color='g', alpha=.50)

# Title and labels
plt.title('Common Salary Ranges')
plt.xlabel('Salary')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# ## 2. Create a bar chart of average salary by title.

# %%
# Get average salary and title from the View Created in the Postgres Employee_DB using connection created in previous steps using SQLAlchemy 
avg_sal_df = pd.read_sql('SELECT title, Avg_Salary FROM vw_emp_title_avg_sal',con=engine).set_index('title')
avg_sal_df

# Create a bar chart
avg_sal_plot = avg_sal_df.plot(kind='bar', color='g', alpha=.50, figsize=(10,5))

# Title and labels
avg_sal_plot.set_title('Average Salary by Title')
avg_sal_plot.set_xlabel('Title')
avg_sal_plot.set_ylabel('Average Salary')
plt.tight_layout()
plt.show()
